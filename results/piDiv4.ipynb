# %% [markdown]
# $$\gamma = \displaystyle\frac{\pi}{4}$$

# %% [markdown]
# Параметры системы
#
# N = 128
#
# mu = 0.1
#
# d = 0.3
#
# omega = np.ones(N)
#
# R = np.ones(N)
#
# gamma = np.pi/4
#
# phi0 =  np.arange(0, 2*np.pi, 2*np.pi/N)

# %% [markdown]
# R1: 0.9999999999999999
#
# R2: 1.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
