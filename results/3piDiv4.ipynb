# %% [markdown]
# $$\gamma = \displaystyle\frac{3\pi}{4}$$

# %% [markdown]
# Параметры системы
#
# N = 128
#
# mu = 0.1
#
# d = 0.3
#
# omega = np.ones(N)
#
# R = np.ones(N)
#
# gamma = np.pi/4
#
# phi0 =  np.arange(0, 2*np.pi, 2*np.pi/N)

# %% [markdown]
# R1: 0.033502299979086436
#
# R2: 0.02333343839582851

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
