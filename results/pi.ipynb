# %% [markdown]
# $$\gamma = \pi$$

# %% [markdown]
# Параметры системы
#
# N = 128
#
# mu = 0.1
#
# d = 0.3
#
# omega = np.ones(N)
#
# R = np.ones(N)
#
# gamma = np.pi/4
#
# phi0 =  np.arange(0, 2*np.pi, 2*np.pi/N)

# %% [markdown]
# R1: 0.034842318023757785
#
# R2: 0.026888893662345183

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
